# %% [markdown]
# **Get the runtime details**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cat /etc/lsb-release
# Out:
# DISTRIB_ID=Ubuntu
# DISTRIB_RELEASE=18.04
# DISTRIB_CODENAME=bionic
# DISTRIB_DESCRIPTION="Ubuntu 18.04.5 LTS"

# %% [markdown]
# **Update the Repo list**

# %%
# !apt-get update
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [696 B]
# Hit:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Hit:9 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# ...

# %% [markdown]
# **Show the current working directory**

# %%
# %pwd
# Out:
# '/content'

# %%
# !cp "/content/drive/My Drive/PKM COMVIS/to_train/model_4/backupdarknet.zip"
# Out:
# cp: missing destination file operand after '/content/drive/My Drive/PKM COMVIS/to_train/model_4/backupdarknet.zip'
# Try 'cp --help' for more information.

# %% [markdown]
# **Unzip the darknet zip file to the /content folder**

# %%
# !unzip "/content/drive/My Drive/PKM COMVIS/weight/model_4/backup/darknet.zip"
# Out:
# Archive:  /content/drive/My Drive/PKM COMVIS/weight/model_4/backup/darknet.zip
#    creating: darknet/.circleci/
#   inflating: darknet/.circleci/config.yml
#   inflating: darknet/.gitignore
#   inflating: darknet/.travis.yml
#    creating: darknet/3rdparty/
#    creating: darknet/3rdparty/pthreads/
#    creating: darknet/3rdparty/pthreads/bin/
#   inflating: darknet/3rdparty/pthreads/bin/pthreadGC2.dll
#   inflating: darknet/3rdparty/pthreads/bin/pthreadVC2.dll
#    creating: darknet/3rdparty/pthreads/include/
#   inflating: darknet/3rdparty/pthreads/include/pthread.h
#   inflating: darknet/3rdparty/pthreads/include/sched.h
#   inflating: darknet/3rdparty/pthreads/include/semaphore.h
#    creating: darknet/3rdparty/pthreads/lib/
#   inflating: darknet/3rdparty/pthreads/lib/libpthreadGC2.a
#   inflating: darknet/3rdparty/pthreads/lib/pthreadVC2.lib
#    creating: darknet/3rdparty/stb/
#    creating: darknet/3rdparty/stb/include/
# ...

# %% [markdown]
# **Go inside the darknet folder of our runtime**

# %%
# %cd /content/darknet
# Out:
# /content/darknet

# %% [markdown]
# **Install dos2unix to convert dos files to unix encoding**

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 68 not upgraded.
# Need to get 351 kB of archives.
# After this operation, 1,267 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dos2unix amd64 7.3.4-3 [351 kB]
# Fetched 351 kB in 1s (473 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package dos2unix.
# ...

# %% [markdown]
# **Convert all files in darknet folder to unix encoding**

# %%
# !find . -type f -print0 | xargs -0 dos2unix
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/37_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/111_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/123_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/55_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/114_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/85_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/73_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/98_7.png
# ...

# %% [markdown]
# **Give executable permission for files in /content/darknet**

# %%
# !chmod +x /content/darknet

# %% [markdown]
# **make sure of the current directory**

# %%
# %pwd
# Out:
# '/content/darknet'

# %% [markdown]
# **Compile the darknet framework**

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:935:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1136:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %% [markdown]
# **Test the darkent framework with sample object detection**
#
# > Indented block

# %%
# !cp "/content/drive/My Drive/PKM COMVIS/weight/model_4/backup/yolov4-tiny_best.weights" "tiny_weight.weights"

# %%
# !./darknet detector test cfg/coco.data cfg/yolov4.cfg yolov4.weights data/person.jpg
# !./darknet detector test dataset/kendaraan.data kendaraan_yolov4.cfg /content/drive/'My Drive'/kendaraan_weight/backup/kendaraan_yolov4_last.weights data/bus.jpg 
# !./darknet detector test dataset/kendaraan.data kendaraan_yolov4.cfg /content/drive/'My Drive'/kendaraan_weight/backup/kendaraan_yolov4_best.weights data/bus.jpg 
# !./darknet detector demo kendaraan/data/kendaraan.data kendaraan/cfg/kendaraan_yolov4.cfg /content/drive/'My Drive'/kendaraan_weight/backup2/backup/kendaraan_yolov4_best.weights /content/drive/"My Drive"/"PKM COMVIS"/videos/"vod for yolo 2.mp4" -out_filename /content/drive/"My Drive"/"PKM COMVIS"/"Video Output"/"out model2.mp4" -dont_show -ext_output

# %% [markdown]
# **Remove the default backup folder of darknet in runtime**

# %%
# !./darknet detector map kendaraan/data/kendaraan.data kendaraan/cfg/kendaraan_yolov4.cfg tiny_weight.weights
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
# net.optimized_memory = 0
# mini_batch = 1, batch = 64, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    832 x 832 x   3 ->  832 x 832 x  32 1.196 BF
#    1 conv     64       3 x 3/ 2    832 x 832 x  32 ->  416 x 416 x  64 6.380 BF
#    2 conv     64       1 x 1/ 1    416 x 416 x  64 ->  416 x 416 x  64 1.418 BF
#    3 route  1 		                           ->  416 x 416 x  64
#    4 conv     64       1 x 1/ 1    416 x 416 x  64 ->  416 x 416 x  64 1.418 BF
#    5 conv     32       1 x 1/ 1    416 x 416 x  64 ->  416 x 416 x  32 0.709 BF
#    6 conv     64       3 x 3/ 1    416 x 416 x  32 ->  416 x 416 x  64 6.380 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 416 x 416 x  64 0.011 BF
# ...

# %%
# !rm /content/darknet/backup -r

# %% [markdown]
# **Create a symbolic link from runtime darknet folder to google drive backup folder with the name 'backup'**

# %%
# !ln -s /content/drive/'My Drive'/"PKM COMVIS"/weight/model_4 /content/darknet

# %% [markdown]
# **check the directory**

# %%
# %pwd

# %% [markdown]
# **Proceed with fresh Training Using the cov dataset**

# %%
# !./darknet detector train kendaraan/data/kendaraan.data yolov4-tiny.cfg yolov4.tiny.conv.29 -dont_show -map
# darknet.exe detector train dataset/kendaraan.data kendaraan_yolov4.cfg yolov4.conv.137 -map

# %% [markdown]
# **Resuming training from the last best weight file**

# %%
# !./darknet detector train kendaraan/data/kendaraan.data kendaraan/cfg/kendaraan_yolov4.cfg /content/drive/'My Drive'/kendaraan_weight/backup2/backup/kendaraan_yolov4_last.weights -dont_show -map
